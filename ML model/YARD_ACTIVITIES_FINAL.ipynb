# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#      Vibration  Motor Internal  Motor Surface  Wire internal1  Wire internal2  \
# 0        10.90           32.75          32.50           30.25           30.12
# 1        11.10           32.75          32.50           30.25           30.19
# 2        10.94           32.75          32.50           30.25           30.12
# 3        10.87           32.75          32.50           30.25           30.19
# 4        10.90           32.75          32.50           30.25           30.12
# ..         ...             ...            ...             ...             ...
# 904       2.63           47.50          44.50           30.25           30.25
# 905       2.59           47.50          44.50           30.31           30.25
# 906       2.75           47.50          44.50           30.31           30.25
# 907       2.55           47.50          44.50           30.25           30.25
# 908       2.63           47.50          44.75           30.25           30.25
#
# ...

# %%
df.shape
# Out:
# (909, 8)

# %%
df.head()
# Out:
#    Vibration  Motor Internal  Motor Surface  Wire internal1  Wire internal2  \
# 0      10.90           32.75           32.5           30.25           30.12
# 1      11.10           32.75           32.5           30.25           30.19
# 2      10.94           32.75           32.5           30.25           30.12
# 3      10.87           32.75           32.5           30.25           30.19
# 4      10.90           32.75           32.5           30.25           30.12
#
#    Motor Stress  Machine stress  Overall Stress
# 0        273.59          273.59          273.59
# 1        278.61          278.61          278.61
# 2        274.59          274.59          274.59
# 3        272.83          272.84          272.84
# 4        273.59          273.59          273.59

# %%
df.describe()
# Out:
#         Vibration  Motor Internal  Motor Surface  Wire internal1  \
# count  909.000000      909.000000     909.000000      909.000000
# mean     4.786205       39.699395      39.105061       30.253828
# std      4.373422        4.516785       3.544900        0.014940
# min     -1.260000       32.750000      32.500000       30.190000
# 25%      0.980000       35.500000      36.000000       30.250000
# 50%      2.590000       39.750000      39.250000       30.250000
# 75%     10.750000       43.750000      42.250000       30.250000
# max     11.570000       47.500000      44.750000       30.310000
#
#        Wire internal2  Motor Stress  Machine stress  Overall Stress
# count      909.000000    909.000000      909.000000      909.000000
# mean        30.215237    120.126425      120.133751      120.129780
# std          0.032228    109.780717      109.772595      109.776806
# min         30.120000    -31.650000      -31.630000      -31.640000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909 entries, 0 to 908
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Vibration       909 non-null    float64
#  1   Motor Internal  909 non-null    float64
#  2   Motor Surface   909 non-null    float64
#  3   Wire internal1  909 non-null    float64
#  4   Wire internal2  909 non-null    float64
#  5   Motor Stress    909 non-null    float64
#  6   Machine stress  909 non-null    float64
#  7   Overall Stress  909 non-null    float64
# dtypes: float64(8)
# memory usage: 56.9 KB

# %%
df.describe().columns
# Out:
# Index(['Vibration', 'Motor Internal', 'Motor Surface', 'Wire internal1',
#        'Wire internal2', 'Motor Stress', 'Machine stress', 'Overall Stress'],
#       dtype='object')

# %%
df
# Out:
#      Vibration  Motor Internal  Motor Surface  Wire internal1  Wire internal2  \
# 0        10.90           32.75          32.50           30.25           30.12
# 1        11.10           32.75          32.50           30.25           30.19
# 2        10.94           32.75          32.50           30.25           30.12
# 3        10.87           32.75          32.50           30.25           30.19
# 4        10.90           32.75          32.50           30.25           30.12
# ..         ...             ...            ...             ...             ...
# 904       2.63           47.50          44.50           30.25           30.25
# 905       2.59           47.50          44.50           30.31           30.25
# 906       2.75           47.50          44.50           30.31           30.25
# 907       2.55           47.50          44.50           30.25           30.25
# 908       2.63           47.50          44.75           30.25           30.25
#
# ...

# %%
df.columns
# Out:
# Index(['Vibration', 'Motor Internal', 'Motor Surface', 'Wire internal1',
#        'Wire internal2', 'Motor Stress', 'Machine stress', 'Overall Stress'],
#       dtype='object')

# %%
df.describe().columns
# Out:
# Index(['Vibration', 'Motor Internal', 'Motor Surface', 'Wire internal1',
#        'Wire internal2', 'Motor Stress', 'Machine stress', 'Overall Stress'],
#       dtype='object')

# %%
X=df[['Vibration', 'Motor Internal', 'Motor Surface', 'Wire internal1',
       'Wire internal2']].values
Y=df[['Overall Stress']].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size=0.8)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((727, 5), (182, 5), (727, 1), (182, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
df[['Vibration', 'Motor Internal', 'Motor Surface', 'Wire internal1',
       'Wire internal2']]
# Out:
#      Vibration  Motor Internal  Motor Surface  Wire internal1  Wire internal2
# 0        10.90           32.75          32.50           30.25           30.12
# 1        11.10           32.75          32.50           30.25           30.19
# 2        10.94           32.75          32.50           30.25           30.12
# 3        10.87           32.75          32.50           30.25           30.19
# 4        10.90           32.75          32.50           30.25           30.12
# ..         ...             ...            ...             ...             ...
# 904       2.63           47.50          44.50           30.25           30.25
# 905       2.59           47.50          44.50           30.31           30.25
# 906       2.75           47.50          44.50           30.31           30.25
# 907       2.55           47.50          44.50           30.25           30.25
# 908       2.63           47.50          44.75           30.25           30.25
#
# [909 rows x 5 columns]

# %%
lr.predict([[10.90,32.75,32.0,30.25,30.12]])
# Out:
# array([[273.58520268]])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
Y_pred=lr.predict(X_test)

# %%
mean_squared_error(Y_pred,Y_test)
# Out:
# 8.996075049410188e-06

# %%
mean_absolute_error(Y_pred,Y_test)
# Out:
# 0.0026273137395414754

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.999999999295359

# %%
import seaborn as sb

# %%
sb.heatmap(df[[  
       'Vibration', 'Motor Internal', 'Motor Surface', 'Wire internal1',
       'Wire internal2', 'Overall Stress']].corr(), annot=True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                 Vibration  Motor Internal  Motor Surface  Wire internal1  \
# Vibration        1.000000       -0.729347      -0.754592       -0.112245
# Motor Internal  -0.729347        1.000000       0.992737        0.133599
# Motor Surface   -0.754592        0.992737       1.000000        0.130265
# Wire internal1  -0.112245        0.133599       0.130265        1.000000
# Wire internal2  -0.382945        0.452195       0.476291        0.095557
# Motor Stress     1.000000       -0.729410      -0.754646       -0.112252
# Machine stress   1.000000       -0.729347      -0.754591       -0.112249
# Overall Stress   1.000000       -0.729378      -0.754618       -0.112251
#
#                 Wire internal2  Motor Stress  Machine stress  Overall Stress
# Vibration            -0.382945      1.000000        1.000000        1.000000
# Motor Internal        0.452195     -0.729410       -0.729347       -0.729378
# Motor Surface         0.476291     -0.754646       -0.754591       -0.754618
# ...
